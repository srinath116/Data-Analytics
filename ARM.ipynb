# %%
import pandas as pd
import numpy as np
import os 
import sys

# %%
data=pd.read_csv("BlackFriday.csv")

# %%
data.head(10)
# Out:
#    User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0  1000001  P00069042      F   0-17          10             A
# 1  1000001  P00248942      F   0-17          10             A
# 2  1000001  P00087842      F   0-17          10             A
# 3  1000001  P00085442      F   0-17          10             A
# 4  1000002  P00285442      M    55+          16             C
# 5  1000003  P00193542      M  26-35          15             A
# 6  1000004  P00184942      M  46-50           7             B
# 7  1000004  P00346142      M  46-50           7             B
# 8  1000004   P0097242      M  46-50           7             B
# 9  1000005  P00274942      M  26-35          20             A
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# ...

# %%
import pyfpgrowth

# %%
data.shape
# Out:
# (99998, 12)

# %%
x=data.iloc[:,0:2]
x=x.values

# %%
len(data['Product_ID'].unique())
# Out:
# 3319

# %%
tr={}
data['User_ID'].unique()
# Out:
# array([1000001, 1000002, 1000003, ..., 1003376, 1003388, 1003443])

# %%
for i in range(len(x)):
    if  x[i][0]  in tr.keys():
        tr[x[i][0]].append(x[i][1])
    else :
        tr[x[i][0]]=[x[i][1]]

# %%
l=[]

# %%
for key,value in tr.items():
    l.append(value)

# %%
patterns = pyfpgrowth.find_frequent_patterns(l, 100)

# %%
import sys

# %%
sys.setrecursionlimit(15000)

# %%
patterns
# Out:
# {('P00276642',): 100,
#  ('P00112342',): 100,
#  ('P00274442',): 100,
#  ('P00170342',): 100,
#  ('P00061142',): 100,
#  ('P00050242',): 100,
#  ('P00010942',): 100,
#  ('P00191642',): 100,
#  ('P00161542',): 100,
#  ('P00330342',): 100,
#  ('P00054942',): 100,
#  ('P00154242',): 100,
#  ('P00005742',): 100,
#  ('P00190842',): 100,
#  ('P00221842',): 100,
#  ('P00295742',): 100,
#  ('P00234542',): 100,
#  ('P00088042',): 100,
#  ('P00329242',): 100,
#  ('P00370642',): 100,
#  ('P00004542',): 100,
#  ('P00162442',): 102,
#  ('P00227142',): 102,
#  ('P00304442',): 102,
#  ('P00241542',): 102,
#  ('P00309242',): 102,
#  ('P00122542',): 102,
#  ('P00341342',): 102,
#  ('P00271042',): 102,
#  ('P00217942',): 102,
#  ('P00355642',): 102,
#  ('P00163442',): 104,
#  ('P00228642',): 104,
#  ('P00358442',): 104,
#  ('P00288042',): 104,
#  ('P00018042',): 104,
#  ('P00049642',): 104,
#  ('P00317942',): 104,
#  ('P00145942',): 104,
#  ('P00183942',): 104,
#  ('P00289842',): 104,
# ...

# %%
rules = pyfpgrowth.generate_association_rules(patterns, 1/pow(10,5))

# %%
rules
# Out:
# {('P00365242',): ((), 0.5),
#  ('P00000642',): ((), 0.5),
#  ('P00105342',): ((), 0.5),
#  ('P00119742',): ((), 0.5),
#  ('P00285842',): ((), 0.5),
#  ('P00034042',): ((), 0.5),
#  ('P00249742',): ((), 0.5),
#  ('P00331942',): ((), 0.5),
#  ('P00127442',): ((), 0.5),
#  ('P00327842',): ((), 0.5),
#  ('P00250842',): ((), 0.5),
#  ('P00221542',): ((), 0.5),
#  ('P00275842',): ((), 0.5),
#  ('P00114442',): ((), 0.5),
#  ('P00321742',): ((), 0.5),
#  ('P00129842',): ((), 0.5),
#  ('P00006942',): ((), 0.5),
#  ('P00177542',): ((), 0.5),
#  ('P00130742',): ((), 0.5),
#  ('P00084442',): ((), 0.5),
#  ('P00192542',): ((), 0.5),
#  ('P00183242',): ((), 0.5),
#  ('P00113042',): ((), 0.5),
#  ('P00117542',): ((), 0.5),
#  ('P00343042',): ((), 0.5),
#  ('P00346142',): ((), 0.5),
#  ('P00127242',): ((), 0.5),
#  ('P00227842',): ((), 0.5),
#  ('P00151742',): ((), 0.5),
#  ('P00058442',): ((), 0.5),
#  ('P00127842',): ((), 0.5),
#  ('P00022942',): ((), 0.5),
#  ('P00216142',): ((), 0.5),
# ...

# %%
from apyori import apriori

# %%
results = list(apriori(l))

# %%
results
# Out:
# []

# %%
trans=[]


trans.append((tuple(x) for x in l))

# %%
trans=list(trans)

# %%
from efficient_apriori import apriori

itemsets, rules = apriori(l, min_support=0.005,  min_confidence=1/pow(10,2))
print(rules)
# Out:
# [{P00057642} -> {P00025442}, {P00025442} -> {P00057642}, {P00278642} -> {P00265242}, {P00265242} -> {P00278642}]
